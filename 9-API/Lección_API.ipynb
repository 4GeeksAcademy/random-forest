# %%
# !pip install investpy yfinance

# %% [markdown]
# # Ejercicio 1: Obtener calendario económico de Investing usando investpy

# %%
import investpy

data = investpy.economic_calendar(
    from_date='12/09/2021',
    to_date  ='13/09/2021'
)

data.head()
# Out:
#        id        date   time                  zone currency importance  \
# 0  436810  12/09/2021  07:59  united arab emirates      AED        low
# 1  435581  12/09/2021  23:45           new zealand      NZD        low
# 2  435584  13/09/2021  00:50                 japan      JPY     medium
# 3  435583  13/09/2021  00:50                 japan      JPY        low
# 4  435582  13/09/2021  00:50                 japan      JPY        low
#
#                                       event  actual forecast previous
# 0         Private Sector Loans (YoY)  (Jul)  -1.80%     None   -1.20%
# 1                          FPI (MoM)  (Aug)    0.3%     None     1.3%
# 2  BSI Large Manufacturing Conditions  (Q3)     7.0     None     -1.4
# 3                          PPI (YoY)  (Aug)    5.5%     5.6%     5.6%
# 4                          PPI (MoM)  (Aug)    0.0%     0.2%     1.1%

# %% [markdown]
# # Ejercicio 2: Consultar el precio de las acciones de investpy en yahoo

# %%
df_stocks_info = investpy.stocks.get_stocks()
df_stocks_info
# Out:
#          country                      name                        full_name  \
# 0      argentina                   Tenaris                          Tenaris
# 1      argentina              PETROBRAS ON  Petroleo Brasileiro - Petrobras
# 2      argentina  Grupo Financiero Galicia       Grupo Financiero Galicia B
# 3      argentina         Ternium Argentina             Ternium Argentina SA
# 4      argentina             Pampa Energia                 Pampa Energia SA
# ...          ...                       ...                              ...
# 39947   zimbabwe                   Padenga                          Padenga
# 39948   zimbabwe          Masimba Holdings         Masimba Holdings Limited
# 39949   zimbabwe                Old Mutual                   Old Mutual PLC
# 39950   zimbabwe               Proplastics                      Proplastics
# 39951   zimbabwe          Cassava SmarTech                 Cassava SmarTech
#
#                isin currency   symbol
# ...

# %%
import yfinance as yf

# Instance of class ticker
ticker = yf.Ticker("TS")

# Get historical market data
ticker.history(period="max")
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2002-12-16 00:00:00-05:00   1.951825   2.142246   1.951825   2.106542
# 2002-12-17 00:00:00-05:00   2.118443   2.189851   2.070838   2.082739
# 2002-12-18 00:00:00-05:00   2.100591   2.100591   2.076788   2.087499
# 2002-12-19 00:00:00-05:00   2.083929   2.149386   2.082739   2.149386
# 2002-12-20 00:00:00-05:00   2.154147   2.285062   2.154147   2.208893
# ...                              ...        ...        ...        ...
# 2023-10-06 00:00:00-04:00  30.860001  31.280001  30.490000  31.059999
# 2023-10-09 00:00:00-04:00  31.700001  32.450001  31.559999  32.410000
# 2023-10-10 00:00:00-04:00  32.520000  32.650002  32.270000  32.590000
# 2023-10-11 00:00:00-04:00  32.669998  32.970001  32.450001  32.889999
# 2023-10-12 00:00:00-04:00  33.009998  33.009998  32.404999  32.474998
#
#                             Volume  Dividends  Stock Splits
# Date
# ...

# %% [markdown]
# # Ejercicio 3: Obtener todos los pares de criptomonedas que trabajan con USDT en binance y posteriormente consultar el precio histórico para uno de esos pares

# %%
import requests

symbols = requests.get('https://api.binance.com/api/v3/ticker/24hr').json()

# %%
type(symbols)
# Out:
# list

# %%
symbols[0]
# Out:
# {'symbol': 'ETHBTC',
#  'priceChange': '-0.00051000',
#  'priceChangePercent': '-0.875',
#  'weightedAvgPrice': '0.05810137',
#  'prevClosePrice': '0.05831000',
#  'lastPrice': '0.05780000',
#  'lastQty': '18.83440000',
#  'bidPrice': '0.05779000',
#  'bidQty': '53.58810000',
#  'askPrice': '0.05780000',
#  'askQty': '15.34340000',
#  'openPrice': '0.05831000',
#  'highPrice': '0.05860000',
#  'lowPrice': '0.05760000',
#  'volume': '19383.36090000',
#  'quoteVolume': '1126.19989928',
#  'openTime': 1697040745179,
#  'closeTime': 1697127145179,
#  'firstId': 423792882,
#  'lastId': 423827742,
#  'count': 34861}

# %%
# Possible intervals:'1m','3m','5m','15m','30m','1h','2h','4h','6h','8h','12h','1d'
data = requests.get('https://api.binance.com/api/v3/klines', params={'symbol':'ETHUSDT', 'interval':'1d','limit': 7}).json()
data[0]
# Out:
# [1696550400000,
#  '1611.79000000',
#  '1662.00000000',
#  '1611.68000000',
#  '1645.03000000',
#  '220507.92860000',
#  1696636799999,
#  '360565723.57884400',
#  539488,
#  '109623.00060000',
#  '179235720.66966800',
#  '0']

# %%
import numpy as np
import pandas as pd
from datetime import datetime

# If succesful we create a dataframe with the data retrieved and store it in our dictionary
df = pd.DataFrame(data=np.array(data)[:,0:7],columns=['Open_time','Open','High','Low','Close','Volume','Close_time'])
# Chane UNIX time to Datetime format
df['Open_time'] = df['Open_time'].apply(lambda x: datetime.utcfromtimestamp(int(x)/1000).strftime('%y-%m-%d %H:%M'))
df['Close_time'] = df['Close_time'].apply(lambda x: datetime.utcfromtimestamp(int(x)/1000).strftime('%y-%m-%d %H:%M'))

# %%
df
# Out:
#         Open_time           Open           High            Low          Close  \
# 0  23-10-06 00:00  1611.79000000  1662.00000000  1611.68000000  1645.03000000
# 1  23-10-07 00:00  1645.03000000  1647.71000000  1630.03000000  1633.57000000
# 2  23-10-08 00:00  1633.56000000  1641.40000000  1616.17000000  1632.84000000
# 3  23-10-09 00:00  1632.85000000  1636.00000000  1546.00000000  1580.13000000
# 4  23-10-10 00:00  1580.13000000  1594.90000000  1550.55000000  1567.63000000
# 5  23-10-11 00:00  1567.62000000  1578.43000000  1544.26000000  1566.87000000
# 6  23-10-12 00:00  1566.86000000  1568.56000000  1534.55000000  1544.27000000
#
#             Volume      Close_time
# 0  220507.92860000  23-10-06 23:59
# 1  101241.57320000  23-10-07 23:59
# 2  149424.66350000  23-10-08 23:59
# 3  340141.09880000  23-10-09 23:59
# 4  240659.32870000  23-10-10 23:59
# 5  260253.96710000  23-10-11 23:59
# 6  150349.34790000  23-10-12 23:59

# %% [markdown]
# # Ejercicio 4: Obtener redes de bicicletas disponibles en citybik y obtener información de las estaciones de una de las redes

# %%
def get_networks():
    url = 'https://api.citybik.es/v2/networks'

    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        return data['networks']
    else:
        print(f"Error al obtener los datos. Código de estado: {response.status_code}")
        return None

redes_bicis = get_networks()

# %%
redes_bicis
# Out:
# [{'company': ['ЗАО «СитиБайк»'],
#   'href': '/v2/networks/velobike-moscow',
#   'id': 'velobike-moscow',
#   'location': {'city': 'Moscow',
#    'country': 'RU',
#    'latitude': 55.75,
#    'longitude': 37.616667},
#   'name': 'Velobike'},
#  {'company': ['Urban Infrastructure Partner'],
#   'href': '/v2/networks/baerum-bysykkel',
#   'id': 'baerum-bysykkel',
#   'location': {'city': 'Bærum',
#    'country': 'NO',
#    'latitude': 59.89455,
#    'longitude': 10.546343},
#   'name': 'Bysykkel'},
#  {'company': ['Comunicare S.r.l.'],
#   'href': '/v2/networks/bicincitta-siena',
#   'id': 'bicincitta-siena',
#   'location': {'city': 'Siena',
#    'country': 'IT',
#    'latitude': 43.3186,
#    'longitude': 11.3306},
#   'name': 'Bicincittà',
#   'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=202'},
#  {'company': ['Cyclopolis Systems'],
#   'href': '/v2/networks/cyclopolis-maroussi',
#   'id': 'cyclopolis-maroussi',
#   'location': {'city': 'Maroussi',
# ...

# %%
def get_stations(network_id):
    url = f'https://api.citybik.es/v2/networks/{network_id}'
    response = requests.get(url)
    print(response.status_code)
    if response.status_code == 200:
        data = response.json()
        if 'stations' in data['network'] and isinstance(data['network']['stations'], list):
            return data['network']['stations']
        else:
            print(f"No se encontraron estaciones para la red '{network_id}'.")
            return []
    else:
        print(f"Error al obtener los datos. Código de estado: {response.status_code}")
        return None

# Ejemplo de uso
network_id = 'sevici'
estaciones = get_stations(network_id)

if estaciones:
    print(f"Estaciones disponibles para la red '{network_id}':")
    for estacion in estaciones:
        print(f"ID: {estacion['id']}, Nombre: {estacion['name']}, Latitud: {estacion['latitude']}, Longitud: {estacion['longitude']}")
else:
    print("No se pudo obtener la información de las estaciones.")
# Out:
# 200
# Estaciones disponibles para la red 'sevici':
# ID: 524f97fd1504270c3a625bf46a79801b, Nombre: 069_CALLE JOSE LAGUILLO, Latitud: 37.39212, Longitud: -5.978636
# ID: e7a6d0742a1f063d85316feba5080154, Nombre: 068_CALLE JUAN ANTONIO CABESTANY, Latitud: 37.39032, Longitud: -5.97988
# ID: 69358e9c464ef43d83c3d4078681f458, Nombre: 066_CALLE ARROYO, Latitud: 37.3936255004888, Longitud: -5.98186917562097
# ID: bf9cbef348acadbddce03092650fecef, Nombre: 194_CALLE PARQUE DE DOÑANA, Latitud: 37.418586, Longitud: -5.973249
# ID: 6c6ff19c8fe5b70ee0546406181023d7, Nombre: 126_AVENIDA REINA MERCEDES, Latitud: 37.358414, Longitud: -5.986423
# ID: 9422d2414a31f20c0216517069d21b97, Nombre: 132_CALLE PAEZ DE RIVERA, Latitud: 37.3636193796288, Longitud: -5.98478516852571
# ID: 5fffeebda40686f94421fc80f1ce58ff, Nombre: 202_AVENIDA MUJER TRABAJADORA, Latitud: 37.411466577192, Longitud: -5.96676313290727
# ...

# %% [markdown]
# APIs vistas en este notebook:
#
# - investpy
# - yfinance
# - binance
# - citybik
